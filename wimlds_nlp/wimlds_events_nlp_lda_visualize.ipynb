# %% [markdown]
# # NLP Analysis of WiMLDS Event Titles
#
# ### Date
# 19-May-2019
#
# ### Reference
# https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/

# %% [markdown]
# ## Import Packages
# The core packages used in this tutorial are `re`, `gensim`, `spacy` and `pyLDAvis`. Besides this we will also using `matplotlib`, `numpy` and `pandas` for data handling and visualization. Let’s import them.

# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint
from datetime import datetime
    
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# spacy for lemmatization
import spacy


# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
import sys
print("Python Version:", sys.version)
# Out:
# Python Version: 3.6.8 |Anaconda, Inc.| (default, Dec 29 2018, 19:04:46)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]

# %%
import matplotlib

# %%
matplotlib.__version__
# Out:
# '2.2.2'

# %%
pd.__version__
# Out:
# '0.23.0'

# %%
df_events = pd.read_csv('wimlds_events_2019_05_08.csv')

# %%
len(df_events)
# Out:
# 439

# %%
list(df_events)
# Out:
# ['chapter_name', 'link', 'local_date', 'name', 'yes_rsvp_count']

# %%
len(df_events.chapter_name.unique())
# Out:
# 43

# %%
df_events.local_date.min()
# Out:
# '1/10/19'

# %%
df_events.local_date.max()
# Out:
# '9/8/18'

# %%
df_events['event_date'] =  pd.to_datetime(df_events['local_date'], format='%x')

# %%
df_events.event_date.min()
# Out:
# Timestamp('2014-01-23 00:00:00')

# %%
df_events.event_date.max()
# Out:
# Timestamp('2019-05-07 00:00:00')

# %%
df_events.head(10)
# Out:
#                                        chapter_name  \
# 0  Abuja Women in Machine Learning and Data Science
# 1  Abuja Women in Machine Learning and Data Science
# 2  Abuja Women in Machine Learning and Data Science
# 3    Lagos Women in Machine Learning & Data Science
# 4    Lagos Women in Machine Learning & Data Science
# 5    Lagos Women in Machine Learning & Data Science
# 6  Nairobi Women in Machine Learning & Data Science
# 7  Nairobi Women in Machine Learning & Data Science
# 8  Nairobi Women in Machine Learning & Data Science
# 9  Nairobi Women in Machine Learning & Data Science
#
#                                                 link local_date  \
# 0  https://www.meetup.com/Abuja-Women-in-Machine-...    3/10/18
# 1  https://www.meetup.com/Abuja-Women-in-Machine-...     5/5/18
# 2  https://www.meetup.com/Abuja-Women-in-Machine-...    7/21/18
# 3  https://www.meetup.com/Lagos-Women-in-Machine-...    6/24/17
# 4  https://www.meetup.com/Lagos-Women-in-Machine-...     8/5/17
# 5  https://www.meetup.com/Lagos-Women-in-Machine-...   11/25/17
# 6  https://www.meetup.com/Nairobi-Women-in-Machin...    12/8/16
# 7  https://www.meetup.com/Nairobi-Women-in-Machin...    1/28/17
# 8  https://www.meetup.com/Nairobi-Women-in-Machin...    2/25/17
# 9  https://www.meetup.com/Nairobi-Women-in-Machin...    3/25/17
#
#                                                 name  yes_rsvp_count  \
# 0               Big Data: From Chaos to Intelligence              17
# 1  Machine Learning: A Focus on Supervised and Un...              35
# 2  Deep Learning: Build An Image Classification M...              20
# 3                                   NLP: Zero to one              59
# 4  Handling Imbalanced Datasets: Building a model...              63
# 5  The ABC-XYZ of Data Science before Machine Lea...              50
# 6  Uncovering patterns and trends using explorato...              17
# 7  Extracting Your Own Web Data using Scraping Tools               8
# 8                       TensorFlow Post-Summit Event              95
# 9  Fueling the Artificial Intelligence revolution...              35
#
#   event_date
# 0 2018-03-10
# 1 2018-05-05
# 2 2018-07-21
# 3 2017-06-24
# 4 2017-08-05
# 5 2017-11-25
# 6 2016-12-08
# 7 2017-01-28
# 8 2017-02-25
# 9 2017-03-25

# %%
# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %%
# Convert to list
data = df_events.name.values.tolist()

# %%
data
# Out:
# ['Big Data: From Chaos to Intelligence',
#  'Machine Learning: A Focus on Supervised and Unsupervised Learning',
#  'Deep Learning: Build An Image Classification Model',
#  'NLP: Zero to one',
#  'Handling Imbalanced Datasets: Building a model and deploying to production',
#  'The ABC-XYZ of Data Science before Machine Learning',
#  'Uncovering patterns and trends using exploratory data analysis',
#  'Extracting Your Own Web Data using Scraping Tools',
#  'TensorFlow Post-Summit Event',
#  'Fueling the Artificial Intelligence revolution with gaming!',
#  'Sentiment Analysis in R',
#  'Unravelling Intel Deep Learning SDK',
#  'TensorFlow : Zero to One',
#  'Treasure Island: Bioinformatics for everyone.',
#  'Deep Learning for Crypt-analysis using TensorFlow',
#  'Prototyping Back Propagation in Excel For Greater Good',
#  'Data Science and Machine Learning in Practice',
#  '#NairobiWiMLDS turns 1 + Christmas Party',
#  'Around the world of data science in 60 minutes or less',
#  'TensorFlow Series: Convolutional Neural Networks for Image Classification',
#  'WiDS Conference Nairobi',
#  'WiDS Nairobi Code-labs',
#  'IndabaXKenya',
#  'Tensorflow Dev Summit Extended',
#  'The Pivotal Career Shift through Data Science and Machine Learning.',
#  'Fireside chat with Sara Hooker',
#  'Fireside chat with Billy Okal',
#  'Fireside chat with Omoju Miller',
#  'A beautiful mind: Hands on Game Theory',
#  'AI in the financial inclusion space in Africa',
#  'Machine Learning Beyond Images and Text',
#  "Google Next '18 Extended Nairobi",
#  '#NairobiWiMLDS turns 2 + Christmas Party',
#  'Python for Data Science Meetup',
#  'Master Data Science in R - Non-standard Evaluation in R',
#  'Indaba X Kenya',
#  'WiMLDS Bengaluru Launch event followed by networking',
#  'Introduction to Deep Learning',
#  'Workshop on how to win Kaggle datascience competitions by WiDS Bengaluru',
#  'StartML Series: Kickstarter Event',
#  'Machine Learning Unplugged',
#  'AI AMA Wednesday with Abi',
#  'Machine Learning Quest',
#  'MLCC Study Jam, New Delhi in collaboration with WiMLDS',
#  'MLCC Study Jam, New Delhi in collaboration with WiMLDS',
#  'Everything ML',
#  'Everything ML Webinar',
#  "Women's Day Mega Meetup",
#  'Everything ML Webinar',
#  'ML Unplugged 2.0',
#  'Everything ML',
#  'Everything ML',
#  'Unriddle Data Science',
#  'Building a ChatBot using Machine Learning',
#  'Discussing Autonomous World and Much More',
#  'Serverless : A new way to build modern application by IBM',
#  'Weekend Hands-On Python Workshop for Beginners',
#  'Women in Data Science Conference 2019, Mumbai',
#  'Machine Learning Unplugged',
#  'Demystifying AI: Kick start your journey to becoming an AI specialist',
#  'Opportunities for Women Entrepreneurs in Technology',
#  'AI on Edge by IOTIOT.in @ COEP-BHAU on 22nd Sep 2018 @ 10.30 am',
#  'Building Machine Learning Model Step by Step',
#  'A Dialogue with Students, Anyone looking to restart their jobs/careers in Pune',
#  'Create and Optimize a linear Regression Model - Speakers - Sr. IBM Developers',
#  'Invitation to join as Core Committee for WiDS Pune',
#  'A walk through the maze of understanding ‚ÄúData Visualization‚Äù',
#  'Ingredients of High Impact Presentations - As per Dale Carnegie Guidelines',
#  'Deep Dive into Hyperparameter Tuning',
#  'Lego Workshop - "Data Science Problem Formulation" - WiDS Pune 2019',
#  '"Design thinking for Data Scientists" - WiDS Pune 2019',
#  'Unmask the Machine Learning Models - WiDS Pune 2019',
#  '"1 Day in Python - Life science case study" - WiDS Pune 2019',
#  '"Convergence of IOT and Artificial Intelligence" - WiDS Pune 2019',
#  'Top Skills That will land you High Paying jobs by 2020',
#  'WiDS Pune 2019 - 1 Day Conference - A Stanford University Initiative',
#  'Fast Tracking Drug Development with Data Analytics and AI',
#  'Kickoff - Meet & Greet',
#  'AHA Moments: Deep Learning in Industry',
#  'Extract Signal from Noise',
#  'Q&A with Michelle Casbon',
#  'Christmas Networking event with R-Ladies',
#  'Vet AI, Questionable Research Practises and more!',
#  'Breaking into Data Science - not as hard as you think!',
#  'Data Cleaning... But Why? with Brooke Clarke',
#  'Lightning talks including detecting brain lesions that cause epilepsy using ML',
#  'Launch event WiMLDS Madrid',
#  'Meetup Navide√±o',
#  '2nd WiMLDS Madrid meetup @BCG',
#  '3rd WiMLDS meetup @IBM',
#  '1st WiMLDS Workshop AWSDeepRacer @awscloud_es',
#  '4th WiMLDS meetup @AWSSummit with PyLadies and RLadies',
#  'WiMLDS POLAND - Pozna≈Ñ #1 MeetUp',
#  'WiMLDS Pozna≈Ñ Meetup #2',
#  'WiMLDS Pozna≈Ñ Meetup #3',
#  'TensorFlow on AWS - Pozna≈Ñ WiMLDS Workshops #1',
#  'WiMLDS Pozna≈Ñ Meetup #4',
#  'WiMLDS Pozna≈Ñ Meetup #5',
#  'WiMLDS Pozna≈Ñ Meetup #6',
#  'Women in Data Science - Pozna≈Ñ Satellite Event 2019',
#  'Warsztat "Data manipulation in R"',
#  'Warsztat "Data manipulation in R"',
#  'R: wizualizacja danych - wprowadzenie do pakietu ggplot2',
#  'R Markdown czyli wizualizacja danych w r√≥≈ºnych formatach (html, pdf i in.)',
#  'DATA Science NETWORKING',
#  'Spotkanie Networkingowe DATA SCIENCE - Dzie≈Ñ kobiet (nie tylko dla kobiet!)',
#  'Data Science at Credit Suisse',
#  'Social Event',
#  'Interest based Targeting',
#  'Data Science Learnathon: From Raw Data to Deployment',
#  'Social Event',
#  'Women in Data Science Conference Zurich',
#  'Data Science and Machine Learning in the service of Women‚Äôs Health',
#  'IWD2019 Kick-Off',
#  'AI at IBM',
#  'IWD Recap Event at Google',
#  'WiMLDS Austin Happy Hour & Networking',
#  'WiMLDS Lightning Talks & Happy Hour - Share Your Work in Machine Learning',
#  'Topics in machine learning',
#  'Application of Machine Learning in Financial Fraud and Crimes',
#  'The progress in speech recognition and its current technology',
#  'Inaugural Meetup Event',
#  'Data Science Stack Showcase',
#  'H2O: Open Source ML Engine for Big Data',
#  'Happy New Year Meet & Greet',
#  'UC Berkeley Meetup',
#  'Dr. Vivienne Ming talks about using Machine Learning to unlock human potential',
#  'DeepDream Hack Night',
#  'An Introduction to Differential Privacy as Applied to Machine Learning',
#  'Data for Good: How change.org applies data science to social change',
#  'Style Algorithms at Stitch Fix',
#  'Workshop: TensorFlow in Python using skflow',
#  'Women, Work and the State of Wage Inequality in 2016',
#  'Model Hyperparameter Tuning',
#  'Machine Learning at Uber: Moving the world with data',
#  'Election Data Hackathon',
#  'Women in Data Science 2017 Conference Screening (WiMLDS+Airbnb+WInD¬≠)',
#  'Machine Learning & Data Science at Quora',
#  '2017 Meet & Greet',
#  'WiMLDS x Fintech',
#  'Data Science at the Chan Zuckerberg Initiative (CZI)',
#  'WiMLDS x FoodTech',
#  'WiMLDS x Calico',
#  'WiMLDS x General Assembly: Talk Data To Me',
#  '[Last Minute] Coding & Coffee',
#  'Code and Coffee',
#  'Code and Coffee',
#  'WiMLDS x Microsoft Reactor',
#  'Code and Coffee',
#  'East Bay Co-working',
#  'Code and Coffee',
#  'WiDS San Francisco @ Stitch Fix',
#  'Women in Data Science 2018 Conference Screening (WiMLDS+Airbnb+SheTalksData)',
#  'Code and Coffee',
#  'Code and Coffee',
#  'Code and Coffee',
#  'Code and Coffee SF',
#  'Code and Coffee East Bay',
#  'WiMLDS x Lyft: Machine Learning Tech Talks',
#  'Code and Coffee East Bay',
#  'Code and Coffee SF',
#  'WiMLDS x Graph Databases',
#  'Code and Coffee East Bay',
#  'Code and Coffee SF',
#  'Code and Coffee East Bay',
#  'Code and Coffee Peninsula',
#  'Code and Coffee SF',
#  'WiMLDS Happy Hour 2018',
#  'Code and Coffee East Bay',
#  'Code and Coffee Peninsula',
#  'Code and Coffee SF',
#  'Code and Coffee East Bay',
#  'Code and Coffee Peninsula',
#  'WiMLDS x PyLadies: Paths to Data Science',
#  'Code and Coffee East Bay',
#  'Code and Coffee Peninsula',
#  'Code and Coffee SF',
#  'Code and Coffee East Bay',
#  'Code and Coffee Peninsula',
#  'Code and Coffee SF',
#  'WiMLDS x Yelp: Machine Learning Best Practices',
#  'Code and Coffee East Bay',
#  'Code and Coffee Peninsula',
#  'Code and Coffee SF',
#  'Code and Coffee East Bay NEW TIME',
#  'Code and Coffee Peninsula',
#  'Code and Coffee SF',
#  'Code and Coffee East Bay',
#  'Code and Coffee Peninsula',
#  'Code and Coffee East Bay',
#  'Code and Coffee Peninsula',
#  'Workshop: Intro to Deep Learning NLP with PyTorch',
#  'Code and Coffee East Bay',
#  'Code and Coffee Peninsula',
#  'Code and Coffee East Bay',
#  'Code and Coffee Peninsula',
#  'Code and Coffee East Bay',
#  'Code and Coffee Peninsula',
#  'Code and Coffee East Bay',
#  'Code and Coffee Peninsula',
#  'Code and Coffee SF',
#  'Code and Coffee East Bay',
#  'Code and Coffee Peninsula',
#  'WiMLDS Happy Hour Winter 2018',
#  'Code and Coffee SF',
#  'Code and Coffee East Bay',
#  'Code and Coffee Peninsula',
#  'WiMLDS x Criteo: ML in Computational Advertising',
#  'Code and Coffee SF',
#  'Code and Coffee East Bay',
#  'Code and Coffee East Bay',
#  'Code and Coffee Peninsula',
#  'Code and Coffee SF',
#  'Code and Coffee East Bay',
#  'WiMLDS x Intuit: Pi Day Meetup',
#  'Code and Coffee East Bay',
#  'Code and Coffee Peninsula',
#  'WiMLDS x StitchFix: Lightning Talk Night',
#  'Code and Coffee East Bay',
#  'Code and Coffee SF',
#  'Code and Coffee East Bay',
#  'Code and Coffee Peninsula',
#  'Women Entrepreneurs in AI Panel Discussion',
#  'Code and Coffee East Bay',
#  'Meet and Greet',
#  'Building a Choropleth Map using D3.js',
#  'Workshop: Submit a Talk to a Data Conference!',
#  'Data Dinner!',
#  'Night Sky Net: Galaxy Classification using Deep Learning',
#  'The Big Data Makeover: How things have changed over 10 years',
#  'Winter Data Dinner',
#  'Diversity in Tech/Engineering Career Day',
#  'Deep Neural Nets in Medical Image Analysis',
#  "International Women's Day Hack Night with Flock",
#  'A night of lightning talks: career lessons, optimization, and data science',
#  'Data Dinner!',
#  'Spark & Sports Analytics',
#  'Small-group Mentor Night: Unblock Yourself!',
#  'A night of lightning talks: fire risk, customer value, ski runs, and flooding',
#  'Holiday Data Happy Hour',
#  'Visualization Workshop: Learn Bokeh',
#  'Women in Data Science (WiDS) Conference - Livestream',
#  'Data Dinner!',
#  'Boulder Startup Week - Data Science Track',
#  'Data Dinner!',
#  'Intro to Kafka',
#  'Machine Learning Failures - For Art!',
#  'Data Dinner!',
#  'Datathon - Round 1',
#  'Datathon - Round 2',
#  'Women in Data Science (WiDS) - Boulder',
#  'Charlottesville WiMLDS Kickoff Social',
#  'Applied Machine Learning Conference (Tom Tom Founders Festival)',
#  'Inaugural Meetup Event',
#  'WiMLDS & PyLadies Women in Data Engineer & Data Science Panel',
#  'Lunch & Learn SQL with Katherine Keenan',
#  'An Evening with Women in DSSG',
#  'Featured Speaker: Daphne Kao',
#  'The Data Scientist and the Data Engineer should be Friends',
#  'Women in Data Science 2017 Conference Screening',
#  'Panel Discussion: Diversity in Data Science Fields',
#  'Data Science Job Search 101 #ProTips',
#  'Women In Data Science 2018: Conference Screening',
#  'Demystifying Deep Learning: Hands-on Workshop',
#  'WiMLDS / Women in Data Science International Women‚Äôs Day Event',
#  'Inaugural WiMLDS meetup in Corpus Christi',
#  'The Democratization of Machine Learning',
#  'Machine Learning in Autonomous Driving',
#  'Integrating Learning with Game Theory for Societal Challenges',
#  'Women in Data Science 2017 Conference Screening',
#  'Troy - Happy Hour & Networking',
#  'Detroit - Happy Hour & Networking',
#  'Careers in Data Science: Panel Discussion',
#  'November Meetup: Open Issues',
#  'WiMLDS Happy Hour and Networking',
#  'WiMLDS Montreal #1: Launch Edition & NeurIPS Conference Special',
#  "WiMLDS Montreal #2: International Women's Day!",
#  'Inaugural Meetup Event',
#  'Learning, Mining and Graphs',
#  'Board Formation',
#  'CANCELLED: A discussion of the evolving definition of data scientist',
#  'Speed data-ing',
#  'Project demo night',
#  'A discussion on the evolving definition of a data scientist',
#  'Grace Hopper Celebration in NYC',
#  'Scaling language understanding in a mono-lingual and multi-lingual context',
#  'A hands-on introduction to R',
#  'An Intro to Machine Learning and Predictive Analytics using Azure ML',
#  'The Future of Technology Transfer',
#  'Resume reviewing & Interviewing tips',
#  'A Hands-on Introduction to D3',
#  'Mobile Network Fraud Analysis and Detection',
#  'Data Science and Emerging Technology at Thomson Reuters',
#  'Statistical Challenges in Oncology at Flatiron Health',
#  'NLP for Automated Grammatical Error Correction',
#  'Before Kaggle: from a business goal to a machine learning problem',
#  'Data Science at Knewton',
#  'Hands-on Introduction to Django',
#  'Healthcare hack-a-thon',
#  'Technical Blogging Workshop',
#  'Intermediate Python Hands-on Workshop',
#  'Data Science + the EHR',
#  'Advanced Machine Learning Tutorial',
#  'Modeling the Success of Software Developer Job Applications',
#  'Image Recognition Through Deep Learning & Neural Networks',
#  'Machine Learning at Bloomberg',
#  'Machine Learning in Finance: Application to Real Asset Pricing',
#  'Random Forest Classification Workshop: Practical Tips',
#  'Big Data Applications at AT&T Labs (featuring hands-on RCloud demo)',
#  'Evening AI Camp @ UN',
#  'Scalable Machine Learning with H2O',
#  'Intro to Azure Machine Learning',
#  'Faster Python Computing with Pyfora',
#  'Data Science and Data Architecture at ADP',
#  'Measuring Software Quality at Cloudera',
#  'Apache Spark Workshop',
#  'Recommendation Engines Workshop',
#  'Neural Networks Workshop',
#  'Women in Data Science 2017 Conference Screening',
#  'Scikit-learn Sprint (to contribute to open source)',
#  '[Cancelled] Digital Data Science at JPMorgan Chase',
#  'Smart Cities Hack',
#  'Digital Data Science at JPMorgan Chase',
#  'Tensorflow for Deep Learning',
#  'Building Efficient Pipelines in Apache Spark',
#  'PySpark Workshop',
#  'Machine Learning at Spotify',
#  'STAN Workshop',
#  'Enigma and the Big Data Picture',
#  'Pondering Predictability',
#  'Female CEOs of AI Centered Companies',
#  'Investigating Complex Data Relationships through Graphs',
#  'Tech Humanism: Data, Meaning, and Human Experience',
#  'Real World Interactive Learning',
#  'Women In Tech Event - Deep Learning Talk: Convolutional Neural Networks',
#  'Women in Data Conference NYC',
#  '#PressforProgress: Women in Data',
#  'Bayesian inference for A/B testing',
#  'Machine Learning at Capital One',
#  'Bot in a Day Workshop',
#  'Managing Up: Build a better relationship with your boss',
#  'A Night of Diversity and Data Viz @ McKinsey',
#  'GraphHack 2018: Neo4j Buzzword Bingo Hackathon',
#  'Scikit-learn Sprint (to contribute to open source)',
#  'Kristen Sosulski of NYU + Exploring Public Data with Enigma',
#  'Intro To Neo4j Graph Database (@NY Times)',
#  'Panel: How to Start a Tech Meetup (registration link is below)',
#  'Tips for Better Predictive Models (@Foursquare)',
#  'Understanding Probability Theory With Exercises in R and Python',
#  'Women in Data Science (WiDS) Conference NYC [register with SAP]',
#  'Data Science & Artificial Intelligence Research at AT&T Labs & Xandr (AppNexus)',
#  'Diversity as a Data Science Imperative [see link for registration]',
#  'Machine Learning w/Graph Algorithms+Cypher for Apache Spark [register w/Neo4j]',
#  'Facebook Artificial Intelligence (FB AI)',
#  'PyGotham Proposal (CFP) Brainstorming [** RSVP with PyLadies **]',
#  'Is it time for a PhD in Data Science?',
#  'Data Science Driving Value at MetLife',
#  'Intern lightning talks and Data Science at RTI International',
#  'Tales from the World of Health Analytics Strategic Consulting',
#  'Women in Data Science Conference Screening + career panel',
#  'To be Healthy, Wealthy, and Wise: Using Decision Modeling to Personalize Policy',
#  'Data science in high-tech manufacturing, agriculture + fin-tech',
#  'Partner Event: Livestream of Women in Data Science Conference w/free lunch!',
#  'Partner Event: Research Triangle Analysts Annual Analytics Forward',
#  'Partner Event: Triangle Machine Learning Day',
#  'Partner event: Analytics in Action: Trends You Need to Know',
#  'How to Build Medical Scoring Systems (Machine Learning in Health Care series)',
#  'Introduction to Modern Machine Learning Techniques',
#  'Partner event: Data + Women + Triangle Holiday potluck',
#  'Why Health Care Needs Another OR (Machine Learning in Health Care series)',
#  'Target Hosts: Pittsburgh Women in Machine Learning and Data Science',
#  'Robotics and Data Science: A Visit to the National Robotics Engineering Center',
#  'An Evening at Petuum: Artificial Intelligence For All!',
#  'Women in Data Science Conference',
#  'Meet and Greet in Seattle',
#  'Human-Centered Data Science Meetup',
#  "What's Next for VT WiMLDS",
#  'Social for the Data-Curious',
#  'How to Get Started in Data Science and Machine Learning',
#  'Friday Afternoon Data Hangout',
#  'Co-working Lunch',
#  'Generative Art Talk at Champlain',
#  'Halloween Social for the Data Curious',
#  'Chris Danforth Talks Complexity, Big Data & Social Networks @ Champlain',
#  'Ladies Hang & Talk Data',
#  'Intro to Python Course!',
#  "Ladies' Taco Tuesday: Newcomers encouraged!",
#  '[RESCHEDULED] Intro to Python Course Part 2!',
#  'Dinner at New World Tortilla & Viral Ideas Lecture at Generator!',
#  'Intro to Python: Part 3',
#  'Conquering imposter syndrome over Sunday morning tea',
#  'Drinks @ Waterworks',
#  'Wine Wednesday @ Daily Planet',
#  'Goal-Setting Afternoon Tea',
#  '#BTVdev Slack Tech Community Meetup',
#  'Data Visualization Artist Talk: Katie McCurdy, PictalHealth',
#  'Lisa Soros on Creating Creativity: Artificial Life and Evolution in Design',
#  'Sector Mash Meetup from #CodeforBTV',
#  'Where Have all The Women Gone? #WomenInTech Panel Discussion',
#  'Reckless Ideas Lecture: More Data, More Problems (Julia Vallera & Randall Harp)',
#  'Winter Party and Rapid Fire Talks',
#  'Road trip! Processing Community Day in Boston',
#  'Leading with Logic: A Mixer for Women in Business and Technology',
#  'Road Trip! Processing Community Day in Montreal + Alexander Calder @ MMFA',
#  'Global Diversity CFP Day: How to Submit Presentation Proposals to Tech Events',
#  'Movie Night! WiDS Conference Pre-Party',
#  'Women in Data Science Burlington Conference',
#  'Primer meetup + Nos visita Tamara Broderick!',
#  'Reuni√≥n informal',
#  'Taller de introducci√≥n a Python',
#  'Happy Hour de Inaugura√ß√£o do WiMLDS S√£o Paulo',
#  "Women's day special with Spotify on user personalisation & Deep Learning & Art",
#  'Ethics, Bias & Algorithmic Fairness in the world of Artificial Intelligence',
#  'Casual get together/ mentorship session',
#  'Code and coffee',
#  'AI and the Future of Work - Dr. Stella Lee',
#  'Thick Data: Importance of Qualitative Methods in Data Science',
#  'El impacto de Machine Learning y primeros pasos en Python.',
#  'Transfer Learning con PyTorch',
#  'Herramientas para Data Science',
#  'Herramientas en Data Science y Machine Learning',
#  'Haciendo carrera en Machine Learning - Inteligencia Artificial',
#  'Kickoff Introductory Session - Meet and Greet',
#  'R + AI Share & Tell (R-Ladies PDX Shared Event)',
#  'R + AI Share & Tell (R-Ladies PDX Shared Event)',
#  "(Portland School of AI) Fast.ai's Practical Deep Learning for Coders v3",
#  "(Portland School of AI) Fast.ai's Practical Deep Learning for Coders v3",
#  'Halifax Women in Data Science Social (Fireside chat, demos)',
#  'Women in Machine Learning/Data Science Meetup #2',
#  'Edmonton WiMLDS Kickoff',
#  'Introduction to Python Workshop',
#  'Kick-off Organisers Meeting',
#  'Kickoff meeting',
#  'Geospatial AI',
#  'Manila WiMLDS #1',
#  'First Meetup and Lightning Talks',
#  'Machine Learning / Data Science 101',
#  'Traffic Lights Detection using Tensorflow - Onsite workshop',
#  'Intro. to Metadata for the Teaching of Literature to Promote Digital Humanities']

# %%
len(data)
# Out:
# 439

# %% [markdown]
# ---

# %% [markdown]
# # Topic modeling visualization – How to present the results of LDA models?
#
# https://www.machinelearningplus.com/nlp/topic-modeling-visualization-how-to-present-results-lda-models/
#
# Updated:  29-May-2019

# %% [markdown]
# ## 1. Introduction
# In topic modeling with gensim, we followed a structured workflow to build an insightful topic model based on the Latent Dirichlet Allocation (LDA) algorithm.
#
# In this post, we will build the topic model using gensim’s native LdaModel and explore multiple strategies to effectively visualize the results using matplotlib plots.
#
# I will be using a portion of the 20 Newsgroups dataset since the focus is more on approaches to visualizing the results.
#
# Let’s begin by importing the packages and the 20 News Groups dataset.

# %%
import sys
import matplotlib
import pandas as pd
# %matplotlib inline

# %%
print("Python Version:", sys.version)
print(matplotlib.__version__)
print(pd.__version__)
# Out:
# Python Version: 3.6.8 |Anaconda, Inc.| (default, Dec 29 2018, 19:04:46)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# 2.2.2
# 0.23.0

# %%
import sys
# !{sys.executable} -m spacy download en
import re, numpy as np, pandas as pd
from pprint import pprint

# Gensim
import gensim, spacy, logging, warnings
import gensim.corpora as corpora
from gensim.utils import lemmatize, simple_preprocess
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt

# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use', 'not', 'would', 'say', 'could', \
                   '_', 'be', 'know', 'good', 'go', 'get', 'do', 'done', 'try', 'many', \
                   'some', 'nice', 'thank', 'think', 'see', 'rather', 'easy', 'easily', \
                   'lot', 'lack', 'make', 'want', 'seem', 'run', 'need', 'even', 'right', \
                   'line', 'even', 'also', 'may', 'take', 'come'])

# %matplotlib inline
warnings.filterwarnings("ignore",category=DeprecationWarning)
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

# %% [markdown]
# ## Read in data

# %%
df_events = pd.read_csv('wimlds_events_2019_05_08.csv')
len(df_events)
df_events['event_date'] =  pd.to_datetime(df_events['local_date'], format='%x')

# %%
df_events.head(10)
# Out:
#                                        chapter_name  \
# 0  Abuja Women in Machine Learning and Data Science
# 1  Abuja Women in Machine Learning and Data Science
# 2  Abuja Women in Machine Learning and Data Science
# 3    Lagos Women in Machine Learning & Data Science
# 4    Lagos Women in Machine Learning & Data Science
# 5    Lagos Women in Machine Learning & Data Science
# 6  Nairobi Women in Machine Learning & Data Science
# 7  Nairobi Women in Machine Learning & Data Science
# 8  Nairobi Women in Machine Learning & Data Science
# 9  Nairobi Women in Machine Learning & Data Science
#
#                                                 link local_date  \
# 0  https://www.meetup.com/Abuja-Women-in-Machine-...    3/10/18
# 1  https://www.meetup.com/Abuja-Women-in-Machine-...     5/5/18
# 2  https://www.meetup.com/Abuja-Women-in-Machine-...    7/21/18
# 3  https://www.meetup.com/Lagos-Women-in-Machine-...    6/24/17
# 4  https://www.meetup.com/Lagos-Women-in-Machine-...     8/5/17
# 5  https://www.meetup.com/Lagos-Women-in-Machine-...   11/25/17
# 6  https://www.meetup.com/Nairobi-Women-in-Machin...    12/8/16
# 7  https://www.meetup.com/Nairobi-Women-in-Machin...    1/28/17
# 8  https://www.meetup.com/Nairobi-Women-in-Machin...    2/25/17
# 9  https://www.meetup.com/Nairobi-Women-in-Machin...    3/25/17
#
#                                                 name  yes_rsvp_count  \
# 0               Big Data: From Chaos to Intelligence              17
# 1  Machine Learning: A Focus on Supervised and Un...              35
# 2  Deep Learning: Build An Image Classification M...              20
# 3                                   NLP: Zero to one              59
# 4  Handling Imbalanced Datasets: Building a model...              63
# 5  The ABC-XYZ of Data Science before Machine Lea...              50
# 6  Uncovering patterns and trends using explorato...              17
# 7  Extracting Your Own Web Data using Scraping Tools               8
# 8                       TensorFlow Post-Summit Event              95
# 9  Fueling the Artificial Intelligence revolution...              35
#
#   event_date
# 0 2018-03-10
# 1 2018-05-05
# 2 2018-07-21
# 3 2017-06-24
# 4 2017-08-05
# 5 2017-11-25
# 6 2016-12-08
# 7 2017-01-28
# 8 2017-02-25
# 9 2017-03-25

# %% [markdown]
# ## 2. Import NewsGroups Dataset
# Let’s import the news groups dataset and retain only 4 of the target_names categories.

# %%
# Import Dataset
df = df_events.copy()
print(df.shape)  #> (2361, 3)
df = df.drop(["local_date", "yes_rsvp_count", "link"], axis=1)
df.head()
# Out:
# (439, 6)
#                                        chapter_name  \
# 0  Abuja Women in Machine Learning and Data Science
# 1  Abuja Women in Machine Learning and Data Science
# 2  Abuja Women in Machine Learning and Data Science
# 3    Lagos Women in Machine Learning & Data Science
# 4    Lagos Women in Machine Learning & Data Science
#
#                                                 name event_date
# 0               Big Data: From Chaos to Intelligence 2018-03-10
# 1  Machine Learning: A Focus on Supervised and Un... 2018-05-05
# 2  Deep Learning: Build An Image Classification M... 2018-07-21
# 3                                   NLP: Zero to one 2017-06-24
# 4  Handling Imbalanced Datasets: Building a model... 2017-08-05

# %% [markdown]
# ## 3. Tokenize Sentences and Clean
# Removing the emails, new line characters, single quotes and finally split the sentence into a list of words using gensim’s simple_preprocess(). Setting the deacc=True option removes punctuations.

# %%
def sent_to_words(sentences):
    for sent in sentences:
        sent = re.sub('\S*@\S*\s?', '', sent)  # remove emails
        sent = re.sub('\s+', ' ', sent)  # remove newline chars
        sent = re.sub("\'", "", sent)  # remove single quotes
        sent = gensim.utils.simple_preprocess(str(sent), deacc=True) 
        yield(sent)  

# Convert to list
data = df.name.tolist()
data_words = list(sent_to_words(data))
print(data_words[:1])
# [['from', 'irwin', 'arnstein', 'subject', 're', 'recommendation', 'on', \
#'duc', 'summary', 'whats', 'it', 'worth', 'distribution', 'usa', 'expires', 'sat', 'may', 'gmt', ...trucated...]]
# Out:
# [['big', 'data', 'from', 'chaos', 'to', 'intelligence']]

# %%
len(data)
# Out:
# 439

# %% [markdown]
# ## 4. Build the Bigram, Trigram Models and Lemmatize
# Let’s form the bigram and trigrams using the Phrases model. This is passed to Phraser() for efficiency in speed of execution.
#
# Next, lemmatize each word to its root form, keeping only nouns, adjectives, verbs and adverbs.
#
# We keep only these POS tags because they are the ones contributing the most to the meaning of the sentences. Here, I use spacy for lemmatization.

# %%
# change threshold below from 100 to 15

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=15) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=15)  
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# !python3 -m spacy download en  # run in terminal once
def process_words(texts, stop_words=stop_words, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """Remove Stopwords, Form Bigrams, Trigrams and Lemmatization"""
    texts = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]
    texts = [bigram_mod[doc] for doc in texts]
    texts = [trigram_mod[bigram_mod[doc]] for doc in texts]
    texts_out = []
    nlp = spacy.load('en', disable=['parser', 'ner'])
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    # remove stopwords once more after lemmatization
    texts_out = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts_out]    
    return texts_out

data_ready = process_words(data_words)  # processed Text Data!
# Out:
# /Users/reshamashaikh/anaconda3/lib/python3.6/site-packages/gensim/models/phrases.py:494: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %% [markdown]
# ## 5. Build the Topic Model
# To build the LDA topic model using LdaModel(), you need the corpus and the dictionary. Let’s create them first and then build the model. The trained topics (keywords and weights) are printed below as well.
#
# *Example:*  If you examine the topic key words, they are nicely segregate and collectively represent the topics we initially chose: Christianity, Hockey, MidEast and Motorcycles. Nice!

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_ready)

# Create Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in data_ready]

# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=25, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=10,
                                           passes=10,
                                           alpha='symmetric',
                                           iterations=100,
                                           per_word_topics=True)

pprint(lda_model.print_topics())
# Out:
# [(22,
#   '0.374*"data_science" + 0.141*"meetup" + 0.131*"python" + 0.052*"world" + '
#   '0.046*"herramienta" + 0.022*"para" + 0.019*"introducci" + 0.019*"tall" + '
#   '0.012*"jpmorgan" + 0.012*"chase"'),
#  (17,
#   '0.221*"workshop" + 0.082*"learn" + 0.061*"traffic" + 0.061*"light" + '
#   '0.061*"onsite" + 0.050*"lunch" + 0.043*"pytorch" + 0.041*"con" + '
#   '0.038*"submit" + 0.011*"pyspark"'),
#  (5,
#   '0.054*"target" + 0.053*"host" + 0.053*"pittsburgh" + 0.034*"bingo" + '
#   '0.034*"buzzword" + 0.034*"graphhack" + 0.029*"lingual" + 0.015*"language" + '
#   '0.015*"mono" + 0.015*"scale"'),
#  (1,
#   '0.056*"business" + 0.050*"problem" + 0.050*"goal" + 0.041*"set" + '
#   '0.041*"tea" + 0.041*"vallera" + 0.041*"randall" + 0.041*"julia" + '
#   '0.041*"harp" + 0.041*"reckless"'),
#  (8,
#   '0.176*"code" + 0.062*"coffee" + 0.052*"coffee_east_bay" + 0.046*"informal" '
#   '+ 0.046*"reuni" + 0.046*"broderick" + 0.046*"nos" + 0.046*"visita" + '
#   '0.046*"tamara" + 0.046*"primer"'),
#  (7,
#   '0.091*"practical" + 0.084*"school" + 0.084*"portland" + 0.084*"coder" + '
#   '0.061*"deep_learn" + 0.043*"build" + 0.036*"user" + 0.036*"personalisation" '
#   '+ 0.035*"series" + 0.030*"neural"'),
#  (12,
#   '0.065*"open" + 0.053*"source" + 0.052*"scikit" + 0.052*"contribute" + '
#   '0.052*"sprint" + 0.045*"predictive" + 0.022*"engine" + '
#   '0.021*"recommendation" + 0.021*"ml" + 0.012*"issue"'),
#  (14,
#   '0.146*"kickoff" + 0.068*"meet" + 0.068*"greet" + 0.056*"meeting" + '
#   '0.054*"center" + 0.044*"introductory" + 0.044*"edmonton" + 0.042*"robotic" '
#   '+ 0.021*"seattle" + 0.021*"visit"'),
#  (2,
#   '0.099*"deep_learning" + 0.093*"introduction" + 0.081*"session" + '
#   '0.038*"casual" + 0.038*"mentorship" + 0.038*"together" + 0.038*"bias" + '
#   '0.038*"algorithmic" + 0.038*"ethic" + 0.038*"fairness"'),
#  (23,
#   '0.220*"wimld" + 0.061*"happy_hour" + 0.059*"manila" + 0.049*"graph" + '
#   '0.045*"special" + 0.040*"paulo" + 0.040*"inaugura" + 0.039*"winter" + '
#   '0.027*"relationship" + 0.022*"next"'),
#  (21,
#   '0.186*"lady" + 0.120*"pdx" + 0.120*"tell" + 0.034*"taco" + 0.034*"newcomer" '
#   '+ 0.034*"tuesday" + 0.034*"encourage" + 0.034*"hang" + 0.016*"bayesian" + '
#   '0.016*"testing"'),
#  (15,
#   '0.142*"day" + 0.056*"artificial" + 0.051*"processing" + 0.051*"road" + '
#   '0.051*"trip" + 0.036*"women" + 0.034*"inteligencia" + 0.034*"carrera" + '
#   '0.034*"haciendo" + 0.033*"montreal"'),
#  (19,
#   '0.314*"woman" + 0.122*"conference" + 0.046*"wid" + 0.039*"technology" + '
#   '0.037*"transfer" + 0.037*"future" + 0.028*"logic" + 0.028*"lead" + '
#   '0.028*"mixer" + 0.028*"burlington"'),
#  (24,
#   '0.284*"ai" + 0.071*"digital" + 0.067*"panel" + 0.052*"geospatial" + '
#   '0.047*"discussion" + 0.036*"hand" + 0.035*"lee" + 0.035*"stella" + '
#   '0.026*"womenintech" + 0.017*"theory"'),
#  (9,
#   '0.313*"datum" + 0.089*"fast" + 0.056*"analytic" + 0.046*"afternoon" + '
#   '0.039*"dinner" + 0.035*"spark" + 0.032*"apache" + 0.020*"friday" + '
#   '0.020*"hangout" + 0.020*"holiday"'),
#  (20,
#   '0.101*"big" + 0.071*"visualization" + 0.054*"enigma" + 0.037*"software" + '
#   '0.028*"job" + 0.023*"picture" + 0.020*"measure" + 0.020*"quality" + '
#   '0.020*"cloudera" + 0.018*"success"'),
#  (18,
#   '0.233*"event" + 0.116*"social" + 0.089*"partner" + 0.067*"tensorflow" + '
#   '0.054*"triangle" + 0.045*"curious" + 0.018*"trend" + 0.018*"action" + '
#   '0.018*"annual" + 0.018*"analyst"'),
#  (6,
#   '0.092*"data" + 0.057*"artist" + 0.057*"mccurdy" + 0.057*"katie" + '
#   '0.057*"pictalhealth" + 0.028*"public" + 0.028*"kristen" + 0.028*"explore" + '
#   '0.028*"nyu" + 0.028*"sosulski"'),
#  (11,
#   '0.239*"talk" + 0.077*"champlain" + 0.053*"human" + 0.039*"generative" + '
#   '0.039*"complexity" + 0.039*"chris" + 0.039*"danforth" + 0.019*"experience" '
#   '+ 0.019*"mean" + 0.019*"humanism"'),
#  (16,
#   '0.079*"idea" + 0.079*"lecture" + 0.064*"neo" + 0.047*"nyc" + 0.046*"time" + '
#   '0.044*"register" + 0.040*"tip" + 0.040*"new" + 0.037*"generator" + '
#   '0.037*"tortilla"')]

# %% [markdown]
# ## 6. What is the Dominant topic and its percentage contribution in each document
# In LDA models, each document is composed of multiple topics. But, typically only one of the topics is dominant. The below code extracts this dominant topic for each sentence and shows the weight of the topic and the keywords in a nicely formatted output.
#
# This way, you will know which document belongs predominantly to which topic.

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=data):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data_ready)
print(len(df_topic_sents_keywords))
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
len(df_dominant_topic)
# Out:
# 439
# 439

# %%
df_dominant_topic.head(20)
# Out:
#     Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0             0            20.0              0.6078
# 1             1            10.0              0.8400
# 2             2             7.0              0.8400
# 3             3            13.0              0.5200
# 4             4             5.0              0.7549
# 5             5            10.0              0.3467
# 6             6             9.0              0.7197
# 7             7             1.0              0.6731
# 8             8            18.0              0.8080
# 9             9             5.0              0.7600
# 10           10             9.0              0.6800
# 11           11             7.0              0.8080
# 12           12            18.0              0.5200
# 13           13             6.0              0.8080
# 14           14             7.0              0.4076
# 15           15             6.0              0.8080
# 16           16            22.0              0.5100
# 17           17            21.0              0.6080
# 18           18            22.0              0.8080
# 19           19             7.0              0.6300
#
#                                              Keywords  \
# 0   big, visualization, enigma, software, job, pic...
# 1   machine_learn, share, tech, community, health,...
# 2   practical, school, portland, coder, deep_learn...
# 3   intro, detection, network, kick, meeting, orga...
# 4   target, host, pittsburgh, bingo, buzzword, gra...
# 5   machine_learn, share, tech, community, health,...
# 6   datum, fast, analytic, afternoon, dinner, spar...
# 7   business, problem, goal, set, tea, vallera, ra...
# 8   event, social, partner, tensorflow, triangle, ...
# 9   target, host, pittsburgh, bingo, buzzword, gra...
# 10  datum, fast, analytic, afternoon, dinner, spar...
# 11  practical, school, portland, coder, deep_learn...
# 12  event, social, partner, tensorflow, triangle, ...
# 13  data, artist, mccurdy, katie, pictalhealth, pu...
# 14  practical, school, portland, coder, deep_learn...
# 15  data, artist, mccurdy, katie, pictalhealth, pu...
# 16  data_science, meetup, python, world, herramien...
# 17  lady, pdx, tell, taco, newcomer, tuesday, enco...
# 18  data_science, meetup, python, world, herramien...
# 19  practical, school, portland, coder, deep_learn...
#
#                                                  Text
# 0                   [big, datum, chaos, intelligence]
# 1   [machine_learn, focus, supervise, unsupervised...
# 2   [deep_learn, build, image, classification, model]
# 3                                               [nlp]
# 4   [handle, imbalanced, dataset, building, model,...
# 5                       [data_science, machine_learn]
# 6   [uncover, pattern, trend, exploratory, datum, ...
# 7               [extract, web, datum, scraping, tool]
# 8                   [tensorflow, post, summit, event]
# 9                          [fuel, revolution, gaming]
# 10                              [sentiment, analysis]
# 11                  [unravel, intel, deep_learn, sdk]
# 12                                       [tensorflow]
# 13        [treasure, island, bioinformatic, everyone]
# 14          [deep_learn, crypt, analysis, tensorflow]
# 15              [prototyp, propagation, excel, great]
# 16            [data_science, machine_learn, practice]
# 17              [nairobiwimld, turn, christma, party]
# 18                [world, data_science, minute, less]
# 19  [tensorflow, series, convolutional, neural, ne...

# %% [markdown]
# ## 7. The most representative sentence for each topic
# Sometimes you want to get samples of sentences that most represent a given topic. This code gets the most exemplar sentence for each topic

# %%
# Display setting to show more characters in column
pd.options.display.max_colwidth = 100

sent_topics_sorteddf_mallet = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]

# Show
sent_topics_sorteddf_mallet.head(25)
# Out:
#     Topic_Num  Topic_Perc_Contrib  \
# 0         0.0              0.7822
# 1         1.0              0.8400
# 2         2.0              0.8080
# 3         3.0              0.8400
# 4         4.0              0.8629
# 5         5.0              0.8800
# 6         6.0              0.8400
# 7         7.0              0.8400
# 8         8.0              0.7200
# 9         9.0              0.8080
# 10       10.0              0.8400
# 11       11.0              0.7822
# 12       12.0              0.7600
# 13       13.0              0.8400
# 14       14.0              0.8800
# 15       15.0              0.8933
# 16       16.0              0.8080
# 17       17.0              0.8400
# 18       18.0              0.8080
# 19       19.0              0.8080
# 20       20.0              0.8400
# 21       21.0              0.8400
# 22       22.0              0.8400
# 23       23.0              0.8080
# 24       24.0              0.8400
#
#                                                                                                Keywords  \
# 0              lightning_talk, first, proposal, cfp, fire, research, presentation, global, rapid, value
# 1                            business, problem, goal, set, tea, vallera, randall, julia, harp, reckless
# 2   deep_learning, introduction, session, casual, mentorship, together, bias, algorithmic, ethic, fa...
# 3                                    night, party, demo, chat, fireside, halifax, pre, movie, hack, viz
# 4                    wednesday, drink, waterworks, syndrome, wine, planet, tea, daily, sunday, imposter
# 5                  target, host, pittsburgh, bingo, buzzword, graphhack, lingual, language, mono, scale
# 6                   data, artist, mccurdy, katie, pictalhealth, public, kristen, explore, nyu, sosulski
# 7          practical, school, portland, coder, deep_learn, build, user, personalisation, series, neural
# 8                code, coffee, coffee_east_bay, informal, reuni, broderick, nos, visita, tamara, primer
# 9                     datum, fast, analytic, afternoon, dinner, spark, apache, friday, hangout, holiday
# 10                   machine_learn, share, tech, community, health, diversity, art, work, care, spotify
# 11          talk, champlain, human, generative, complexity, chris, danforth, experience, mean, humanism
# 12              open, source, scikit, contribute, sprint, predictive, engine, recommendation, ml, issue
# 13            intro, detection, network, kick, meeting, organiser, literature, teach, promote, humanity
# 14               kickoff, meet, greet, meeting, center, introductory, edmonton, robotic, seattle, visit
# 15            day, artificial, processing, road, trip, women, inteligencia, carrera, haciendo, montreal
# 16                               idea, lecture, neo, nyc, time, register, tip, new, generator, tortilla
# 17                        workshop, learn, traffic, light, onsite, lunch, pytorch, con, submit, pyspark
# 18                event, social, partner, tensorflow, triangle, curious, trend, action, annual, analyst
# 19                 woman, conference, wid, technology, transfer, future, logic, lead, mixer, burlington
# 20              big, visualization, enigma, software, job, picture, measure, quality, cloudera, success
# 21                         lady, pdx, tell, taco, newcomer, tuesday, encourage, hang, bayesian, testing
# 22            data_science, meetup, python, world, herramienta, para, introducci, tall, jpmorgan, chase
# 23               wimld, happy_hour, manila, graph, special, paulo, inaugura, winter, relationship, next
# 24                   ai, digital, panel, geospatial, discussion, hand, lee, stella, womenintech, theory
#
#                                                       Representative Text
# 0     [night, lightning_talk, fire, risk, customer, value, ski, flooding]
# 1                          [invitation, join, core, committee, wids_pune]
# 2                                 [casual, together, mentorship, session]
# 3                                  [small, group, mentor, night, unblock]
# 4                     [conquer, imposter, syndrome, sunday, morning, tea]
# 5         [markdown, czyli, wizualizacja, danych, ºnych, formatach, html]
# 6                   [wizualizacja, danych, wprowadzenie, pakietu, ggplot]
# 7                       [deep_learn, build, image, classification, model]
# 8                        [primer, meetup, nos, visita, tamara, broderick]
# 9                                     [friday, afternoon, datum, hangout]
# 10              [machine_learn, focus, supervise, unsupervised, learning]
# 11    [dr, vivienne, ming, talk, machine_learn, unlock, human, potential]
# 12                                              [everything, ml, webinar]
# 13                        [nlp, automate, grammatical, error, correction]
# 14      [healthy, wealthy, wise, decision, modeling, personalize, policy]
# 15  [lisa, soro, create, creativity, artificial, life, evolution, design]
# 16                                      [grace, hopper, celebration, nyc]
# 17                                 [lunch, learn, sql, katherine, keenan]
# 18                                      [tensorflow, post, summit, event]
# 19                         [opportunity, woman, entrepreneur, technology]
# 20                     [walk, maze, understanding, audata, visualization]
# 21                             [lady, taco, tuesday, newcomer, encourage]
# 22                          [boulder, startup, week, data_science, track]
# 23                                   [happy_hour, inaugura, wimld, paulo]
# 24                                  [beautiful, mind, hand, game, theory]

# %% [markdown]
# ## 8. Frequency Distribution of Word Counts in Documents
# When working with a large number of documents, you want to know how big the documents are as a whole and by topic. Let’s plot the document word counts distribution.

# %%
# # original code
# doc_lens = [len(d) for d in df_dominant_topic.Text]

# # Plot
# plt.figure(figsize=(16,7), dpi=160)
# plt.hist(doc_lens, bins = 1000, color='navy')
# plt.text(750, 100, "Mean   : " + str(round(np.mean(doc_lens))))
# plt.text(750,  90, "Median : " + str(round(np.median(doc_lens))))
# plt.text(750,  80, "Stdev   : " + str(round(np.std(doc_lens))))
# #plt.text(750,  70, "1%ile    : " + str(round(np.quantile(doc_lens, q=0.01))))
# #plt.text(750,  60, "99%ile  : " + str(round(np.quantile(doc_lens, q=0.99))))

# plt.gca().set(xlim=(0, 1000), ylabel='Number of Documents', xlabel='Document Word Count')
# plt.tick_params(size=16)
# plt.xticks(np.linspace(0,1000,9))
# plt.title('Distribution of Document Word Counts', fontdict=dict(size=22))
# plt.show()

# %%
# changes made in below
# figsize
# xlim from 1000 to 500 (docs)
# xticks from 1000 to 500
# plt.text(750, 100, ---> 500, 100

# %%
doc_lens = [len(d) for d in df_dominant_topic.Text]

# Plot
plt.figure(figsize=(16,7), dpi=160)
plt.hist(doc_lens, bins = 9, color='navy')
plt.text(30, 100, "Mean   : " + str(round(np.mean(doc_lens))))
plt.text(30, 90, "Median : " + str(round(np.median(doc_lens))))
plt.text(30,  80, "Stdev   : " + str(round(np.std(doc_lens))))
plt.text(30, 70,  "Min     : " + str(round(np.min(doc_lens))))
plt.text(30, 60,  "Max     : " + str(round(np.max(doc_lens))))
#plt.text(750,  70, "1%ile    : " + str(round(np.quantile(doc_lens, q=0.01))))
#plt.text(750,  60, "99%ile  : " + str(round(np.quantile(doc_lens, q=0.99))))

plt.gca().set(xlim=(0, 25), ylim=(0, 125), ylabel='Number of Documents', xlabel='Document Word Count')
plt.tick_params(size=25)
plt.xticks(np.linspace(0,50,5))
plt.title('Distribution of Document Word Counts', fontdict=dict(size=22))
plt.show()

# %%
import seaborn as sns
import matplotlib.colors as mcolors
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

fig, axes = plt.subplots(3,3,figsize=(16,14), dpi=160, sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):    
    df_dominant_topic_sub = df_dominant_topic.loc[df_dominant_topic.Dominant_Topic == i, :]
    doc_lens = [len(d) for d in df_dominant_topic_sub.Text]
    ax.hist(doc_lens, bins = 800, color=cols[i])
    ax.tick_params(axis='y', labelcolor=cols[i], color=cols[i])
    sns.kdeplot(doc_lens, color="black", shade=False, ax=ax.twinx())
    ax.set(xlim=(0, 1000), xlabel='Document Word Count')
    ax.set_ylabel('Number of Documents', color=cols[i])
    ax.set_title('Topic: '+str(i), fontdict=dict(size=16, color=cols[i]))

fig.tight_layout()
fig.subplots_adjust(top=0.90)
plt.xticks(np.linspace(0,10,0.5))
fig.suptitle('Distribution of Document Word Counts by Dominant Topic', fontsize=22)
plt.show()

# %% [markdown]
# ## 9. Word Clouds of Top N Keywords in Each Topic
# Though you’ve already seen what are the topic keywords in each topic, a word cloud with the size of the words proportional to the weight is a pleasant sight. The coloring of the topics I’ve taken here is followed in the subsequent plots as well.

# %%
# 1. Wordcloud of Top N words in each topic
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

cloud = WordCloud(stopwords=stop_words,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=15,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = lda_model.show_topics(formatted=False)
len(topics)
# Out:
# 10

# %%
fig, axes = plt.subplots(3, 3, figsize=(30,20), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=500)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=20))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(5, 2, figsize=(30,20), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=500)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=20))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Word Counts of Topic Keywords
# When it comes to the keywords in the topics, the importance (weights) of the keywords matters. Along with that, how frequently the words have appeared in the documents is also interesting to look.
#
# Let’s plot the word counts and the weights of each keyword in the same chart.`
#
# You want to keep an eye out on the words that occur in multiple topics and the ones whose relative frequency is more than the weight. Often such words turn out to be less important. The chart I’ve drawn below is a result of adding several such words to the stop words list in the beginning and re-running the training process.

# %%
from collections import Counter
topics = lda_model.show_topics(formatted=False)
data_flat = [w for w_list in data_ready for w in w_list]
counter = Counter(data_flat)

out = []
for i, topic in topics:
    for word, weight in topic:
        out.append([word, i , weight, counter[word]])

df = pd.DataFrame(out, columns=['word', 'topic_id', 'importance', 'word_count'])        
df.head()
# Out:
#             word  topic_id  importance  word_count
# 0            big        20    0.101010           6
# 1  visualization        20    0.071067           3
# 2         enigma        20    0.053508           2
# 3       software        20    0.037044           2
# 4            job        20    0.028017           4

# %%
# Plot Word Count and Weights of Topic Keywords
fig, axes = plt.subplots(2, 2, figsize=(10,8), sharey=True, dpi=160)
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]

# %%
for i, ax in enumerate(axes.flatten()):
    print(i, ax)
# Out:
# 0 AxesSubplot(0.125,0.536818;0.352273x0.343182)
# 1 AxesSubplot(0.547727,0.536818;0.352273x0.343182)
# 2 AxesSubplot(0.125,0.125;0.352273x0.343182)
# 3 AxesSubplot(0.547727,0.125;0.352273x0.343182)

# %%
for i, ax in enumerate(axes.flatten()):
    ax.bar(x='word', height="word_count", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.5, alpha=0.3, label='Word Count')
    ax_twin = ax.twinx()
    ax_twin.bar(x='word', height="importance", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.2, label='Weights')
    ax.set_ylabel('Word Count', color=cols[i])
    ax_twin.set_ylim(0, 300); ax.set_ylim(0, 150)
    ax.set_title('Topic: ' + str(i), color=cols[i], fontsize=16)
    ax.tick_params(axis='y', left=False)
    ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')
    #ax.legend(loc='upper left'); ax_twin.legend(loc='upper right')

fig.tight_layout(w_pad=2)    
fig.suptitle('Word Count and Importance of Topic Keywords', fontsize=22, y=1.05)    
plt.show()

# %% [markdown]
# ## 11. Sentence Chart Colored by Topic
# Each word in the document is representative of one of the 4 topics. Let’s color each word in the given documents by the topic id it is attributed to.
# The color of the enclosing rectangle is the topic assigned to the document.

# %%
from IPython.core.debugger import set_trace


# Sentence Coloring of N Sentences
from matplotlib.patches import Rectangle

def sentences_chart(lda_model=lda_model, corpus=corpus, start = 0, end = 13):
    #set_trace()

    corp = corpus[start:end]
    mycolors = [color for name, color in mcolors.TABLEAU_COLORS.items()]

    fig, axes = plt.subplots(end-start, 1, figsize=(20, (end-start)*0.95), dpi=160)       
    axes[0].axis('off')
    for i, ax in enumerate(axes):
        if i > 0:
            corp_cur = corp[i-1] 
            topic_percs, wordid_topics, wordid_phivalues = lda_model[corp_cur]
            word_dominanttopic = [(lda_model.id2word[wd], topic[0]) for wd, topic in wordid_topics]    
            ax.text(0.01, 0.5, "Doc " + str(i-1) + ": ", verticalalignment='center',
                    fontsize=16, color='black', transform=ax.transAxes, fontweight=700)

            # Draw Rectange
            topic_percs_sorted = sorted(topic_percs, key=lambda x: (x[1]), reverse=True)
            ax.add_patch(Rectangle((0.0, 0.05), 0.99, 0.90, fill=None, alpha=1, 
                                   color=mycolors[topic_percs_sorted[0][0]], linewidth=2))

            word_pos = 0.06
            for j, (word, topics) in enumerate(word_dominanttopic):
                if j < 14:
                    ax.text(word_pos, 0.5, word,
                            horizontalalignment='left',
                            verticalalignment='center',
                            fontsize=16, color=mycolors[topics],
                            transform=ax.transAxes, fontweight=700)
                    word_pos += .009 * len(word)  # to move the word for the next iter
                    ax.axis('off')
            ax.text(word_pos, 0.5, '. . .',
                    horizontalalignment='left',
                    verticalalignment='center',
                    fontsize=16, color='black',
                    transform=ax.transAxes)       

    plt.subplots_adjust(wspace=0, hspace=0)
    plt.suptitle('Sentence Topic Coloring for Documents: ' + str(start) + ' to ' + str(end-2), fontsize=22, y=0.95, fontweight=700)
    plt.tight_layout()
    plt.show()

sentences_chart()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-23462acfe941> in <module>()
#      47     plt.show()
#      48
# ---> 49 sentences_chart()
#
# <ipython-input-48-23462acfe941> in sentences_chart(lda_model, corpus, start, end)
#      24             topic_percs_sorted = sorted(topic_percs, key=lambda x: (x[1]), reverse=True)
#      25             ax.add_patch(Rectangle((0.0, 0.05), 0.99, 0.90, fill=None, alpha=1,
# ---> 26                                    color=mycolors[topic_percs_sorted[0][0]], linewidth=2))
#      27
#      28             word_pos = 0.06
#
# IndexError: list index out of range

# %%
# %debug
# Out:
# > <ipython-input-48-23462acfe941>(26)sentences_chart()
#      24             topic_percs_sorted = sorted(topic_percs, key=lambda x: (x[1]), reverse=True)
#      25             ax.add_patch(Rectangle((0.0, 0.05), 0.99, 0.90, fill=None, alpha=1,
# ---> 26                                    color=mycolors[topic_percs_sorted[0][0]], linewidth=2))
#      27
#      28             word_pos = 0.06
#
# ipdb> topic_percs
# [(9, 0.20817098), (20, 0.607829)]
# ipdb> p topic_percs
# [(9, 0.20817098), (20, 0.607829)]

# %% [markdown]
# ## 12. What are the most discussed topics in the documents?
# Let’s compute the total number of documents attributed to each topic.

# %%
# Sentence Coloring of N Sentences
def topics_per_document(model, corpus, start=0, end=1):
    corpus_sel = corpus[start:end]
    dominant_topics = []
    topic_percentages = []
    for i, corp in enumerate(corpus_sel):
        topic_percs, wordid_topics, wordid_phivalues = model[corp]
        dominant_topic = sorted(topic_percs, key = lambda x: x[1], reverse=True)[0][0]
        dominant_topics.append((i, dominant_topic))
        topic_percentages.append(topic_percs)
    return(dominant_topics, topic_percentages)

dominant_topics, topic_percentages = topics_per_document(model=lda_model, corpus=corpus, end=-1)            

# Distribution of Dominant Topics in Each Document
df = pd.DataFrame(dominant_topics, columns=['Document_Id', 'Dominant_Topic'])
dominant_topic_in_each_doc = df.groupby('Dominant_Topic').size()
df_dominant_topic_in_each_doc = dominant_topic_in_each_doc.to_frame(name='count').reset_index()

# Total Topic Distribution by actual weight
topic_weightage_by_doc = pd.DataFrame([dict(t) for t in topic_percentages])
df_topic_weightage_by_doc = topic_weightage_by_doc.sum().to_frame(name='count').reset_index()

# Top 3 Keywords for each Topic
topic_top3words = [(i, topic) for i, topics in lda_model.show_topics(formatted=False) 
                                 for j, (topic, wt) in enumerate(topics) if j < 3]

df_top3words_stacked = pd.DataFrame(topic_top3words, columns=['topic_id', 'words'])
df_top3words = df_top3words_stacked.groupby('topic_id').agg(', \n'.join)
df_top3words.reset_index(level=0,inplace=True)

# %% [markdown]
# Let’s make two plots:
#
# 1. The number of documents for each topic by assigning the document to the topic that has the most weight in that document.
# 2. The number of documents for each topic by by summing up the actual weight contribution of each topic to respective documents.

# %%
from matplotlib.ticker import FuncFormatter

# Plot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4), dpi=120, sharey=True)

# Topic Distribution by Dominant Topics
ax1.bar(x='Dominant_Topic', height='count', data=df_dominant_topic_in_each_doc, width=.5, color='firebrick')
ax1.set_xticks(range(df_dominant_topic_in_each_doc.Dominant_Topic.unique().__len__()))
tick_formatter = FuncFormatter(lambda x, pos: 'Topic ' + str(x)+ '\n' + df_top3words.loc[df_top3words.topic_id==x, 'words'].values[0])
ax1.xaxis.set_major_formatter(tick_formatter)
ax1.set_title('Number of Documents by Dominant Topic', fontdict=dict(size=10))
ax1.set_ylabel('Number of Documents')
ax1.set_ylim(0, 1000)

# Topic Distribution by Topic Weights
ax2.bar(x='index', height='count', data=df_topic_weightage_by_doc, width=.5, color='steelblue')
ax2.set_xticks(range(df_topic_weightage_by_doc.index.unique().__len__()))
ax2.xaxis.set_major_formatter(tick_formatter)
ax2.set_title('Number of Documents by Topic Weightage', fontdict=dict(size=10))

plt.show()

# %% [markdown]
# ## 13. t-SNE Clustering Chart
# Let’s visualize the clusters of documents in a 2D space using t-SNE (t-distributed stochastic neighbor embedding) algorithm.

# %%
# Get topic weights and dominant topics ------------
from sklearn.manifold import TSNE
from bokeh.plotting import figure, output_file, show
from bokeh.models import Label
from bokeh.io import output_notebook

# Get topic weights
topic_weights = []
for i, row_list in enumerate(lda_model[corpus]):
    topic_weights.append([w for i, w in row_list[0]])

# Array of topic weights    
arr = pd.DataFrame(topic_weights).fillna(0).values

# Keep the well separated points (optional)
arr = arr[np.amax(arr, axis=1) > 0.35]

# Dominant topic number in each doc
topic_num = np.argmax(arr, axis=1)

# tSNE Dimension Reduction
tsne_model = TSNE(n_components=2, verbose=1, random_state=0, angle=.99, init='pca')
tsne_lda = tsne_model.fit_transform(arr)

# Plot the Topic Clusters using Bokeh
output_notebook()
n_topics = 4
mycolors = np.array([color for name, color in mcolors.TABLEAU_COLORS.items()])
plot = figure(title="t-SNE Clustering of {} LDA Topics".format(n_topics), 
              plot_width=900, plot_height=700)
plot.scatter(x=tsne_lda[:,0], y=tsne_lda[:,1], color=mycolors[topic_num])
show(plot)

# %% [markdown]
# ## 14. pyLDAVis
# Finally, pyLDAVis is the most commonly used and a nice way to visualise the information contained in a topic model. Below is the implementation for LdaModel().

# %%
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary=lda_model.id2word)
vis

# %% [markdown]
# ## 15. Conclusion
# We started from scratch by importing, cleaning and processing the newsgroups dataset to build the LDA model. Then we saw multiple ways to visualize the outputs of topic models including the word clouds and sentence coloring, which intuitively tells you what topic is dominant in each topic. A t-SNE clustering and the pyLDAVis are provide more details into the clustering of the topics.
#
# Where next? If you are familiar with [scikit learn](https://www.machinelearningplus.com/nlp/topic-modeling-python-sklearn-examples/), you can build and grid search topic models using scikit learn as well.
